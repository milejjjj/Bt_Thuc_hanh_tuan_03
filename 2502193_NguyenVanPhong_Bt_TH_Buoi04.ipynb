# %%
#W4A1
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    sum = 0
    for i in range(1, n + 1):
        sum += i
    print(sum)
# Out:
# 5
# 15

# %%
#W4A2
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()
def check(x):
    if x < 2: return False
    for i in range(2, int(sqrt(x)) + 1):
        if x % i == 0: return False
    return True
if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    if check(n) == True : print("True")
    else: print("False")

# %%
#W4A3
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    sum = 1
    for i in range(1, n + 1):
        sum *= i
    print(sum)

# %%
#W4A4
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    n = abs(n - 0)
    n = int(n)
    cnt = 0
    while n > 0:
        cnt += 1
        n //= 10
    print(cnt)

# %%
#W4A5
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    a = list(map(int, input().split()))
    ok = False
    for i in range(0, n):
        if a[i] == 42:
            ok = True
            break
    if ok == True: print("I've found the meaning of life!")
    else: print("It's a joke!")

# %%
#W4A6
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()
def check(x):
    if x < 2: return False
    for i in range(2, int(sqrt(x)) + 1):
        if x % i == 0: return False
    return True
if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    sum = 0
    a, b = map(int, input().split())
    for i in range(a, b + 1):
        if check(i) == True: sum += i
    print(sum)

# %%
#W4A7
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()
def check(x):
    if x < 2: return False
    for i in range(2, int(sqrt(x)) + 1):
        if x % i == 0: return False
    return True
if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    ans = 0
    for i in range(1, isqrt(n) + 1):
        if n % i == 0:
            if check(i): ans = max(ans, i)
            if(check(n//i)): ans = max(ans, n//i)
    print (ans)

# %%
#W4A8
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()
def check(x):
    y = x[::-1]
    if x == y: return True
    return False
if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    cnt = 0
    while check(str(n)) == False:
        s = str(n)
        s = s[::-1]
        s = int(s)
        cnt += 1
        n += s
    print(cnt, n, sep=' ')

# %%
#W4A9
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()
def check(x):
    y = isqrt(x)
    if y*y == x: return 1
    return 0
if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    ok = False
    for i in range(1, n + 1):
        if check(i):
            ok = True
            print(i, end=' ')
    if ok == False: print("no number")

# %%
#W4A10
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()
def calc(x):
    cnt = 1
    while x != 1:
        cnt += 1
        if x&1: x = 3*x + 1
        else: x //= 2
    return cnt
if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    val = 100000000000
    res = 0
    for i in range(1, n + 1):
        if calc(i) == res: val = min(val, i)
        elif calc(i) > res:
            res = calc(i)
            val = i
    print(val, res, sep=' ')

# %%
#W4A11
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    ans = 0
    for i in range(1, isqrt(n) + 1):
        if n % i == 0:
            if i%2 == 0: ans += 1
            if (n//i != i) and (n//i % 2 == 0): ans += 1
    print(ans)

# %%
#W4A12
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    s, n = map(int, input().split())
    print(int(s*pow(1.007, n)))

# %%
#W4A13
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()
def calc(x):
    ans = 1
    for i in range(2, isqrt(x) + 1):
        if x%i == 0:
            if x // i != i: ans += x//i
            ans += i
    return ans
if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    a, b = map(int, input().split())
    if calc(a) == b and calc(b) == a: print("true")
    else: print("false")

# %%
#W4A14
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()
def gcd(x, y):
    if y == 0: return x
    return gcd(y, x%y)
if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    a, b = map(int, input().split())
    print(gcd(a, b))

# %%
#W4A15
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    a, b = map(int, input().split())
    y = int(b/2 - a)
    x = a - y
    if x + y == a and 2*x + 4*y == b: print(x, y, sep=' ')
    else: print("invalid")

# %%
#W4A16
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    for i in range(1, 100 + 1):
        if i%3 == 0 and i%2 == 0: print(i, end=' ')

# %%
#bai17
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    for i in range(0, 11):
        print(min(i, n), "*", max(i, n), " = " , i*n)

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    a, b = map(int, input().split())
    val = gcd(a, b)
    for i in range(1, val + 1):
        if(a%i == 0 and b % i == 0):
            print(i, end=' ')

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    val = 2
    while val <= n:
        print(val, end = ' ')
        val += 2

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    ok = 1
    while n > 0 and ok == 1:
        if n % 2 == 1:
            ok = 0
        n //= 2
        if n == 1: break
    if ok == 1: print("Yes")
    else: print("No")

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n  = int(input())
    ans = 0
    while n > 0:
        r = n%10
        ans += r
        n //= 10
    print(ans)

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    odd = 0
    even = 0
    while n > 0:
        r = n%10
        if n&1 : odd += 1
        else: even += 1
        n //= 10
    print(odd, even)

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    for i in range (1, n + 1):
        if i*(i + 1) >= 2*n:
            print(i - 1)
            break

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
def sum(n):
  s=0
  for i in range(1,n+1):
    s=s+(1/i)
  return s
A=float(input())
s=0
id=0
while(s<A):
  id+=1
  s=sum(id)
print(id)

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    ok = 1
    minval = 1000000000000
    maxval = -1000000000000
    while ok:
        x = int(input())
        if x == -1: break
        else:
            minval = min(minval, x)
            maxval = max(maxval, x)
    print(minval, maxval)

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    n = int(input())
    last1 = 0
    last2 = 1
    while last1 + last2 <= n:
        tmp1 = last1
        tmp2 = last2
        last1 = tmp2
        last2 = tmp1 + tmp2
    print(last2)

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    s = input()
    cnt = 0
    for x in s:
        if x == ' ':
            cnt += 1
    print(cnt + 1)

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    s = input()
    for i in range(0, len(s)):
        if s[i] == ' ': break
        print(s[i], end='')

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    s = input()
    a = []
    val = 0
    for i in range(0, len(s)):
        if s[i] == ',':
            a.append(val)
            val = 0

        else:
            val = val*10 + int(s[i])
    a.append(val)
    ans = 0
    for x in a: ans += x
    print(ans)

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    s = input()
    Hoa, Thuong, So = 0, 0, 0
    for x in s:
        if x >= '0' and x <= '9': So += 1
        if x >= 'A' and x <= 'Z': Hoa += 1
        if x >= 'a' and x <= 'z': Thuong += 1
    print(Hoa, Thuong, So)

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    s = input()
    ans = 0
    for x in s:
        if x >= '0' and x <= '9':
            ans += int(x)
    print(ans)

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    s = input()
    Hoa, Thuong, So = 0, 0, 0
    for x in s:
        if x >= '0' and x <= '9': So += 1
        if x >= 'A' and x <= 'Z': Hoa += 1
        if x >= 'a' and x <= 'z': Thuong += 1
    if So >= 1 and Hoa >= 1 and Thuong >= 1 and len(s) >= 6: print("True")
    else: print("False")

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    a = []
    s = input()
    s = s[::-1]
    for i in range(0, len(s)):
        if(i != 0 and i%3 == 0): a.append('.')
        a.append(s[i])
    a = a[::-1]
    for x in a:
        print(x, end='')

# %%
import sys
from math import*
from collections import deque
row, col = 1000, 1000
import turtle
#screen = turtle.Screen()
#screen.title()

if __name__ == '__main__':
    try:
        sys.stdin = open("task.in", "r")
        sys.stdout = open("task.out", "w")
    except FileNotFoundError:
        pass
    a = input()
    b = input()
    ans = []
    if b in a:
        s = a.find(b)
        e = s + len(b) - 1
        for i in range(0, s):
            ans.append(a[i])
        for i in range(e + 1, len(a)):
            ans.append(a[i])
        for x in ans:
            print(x, end='')
